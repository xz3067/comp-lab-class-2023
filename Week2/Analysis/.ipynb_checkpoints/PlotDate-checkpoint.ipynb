# %%
import numpy as np
import pandas as pd
import os
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.figure(figsize=(7,6),dpi=600)
font = {'family' : 'Microsoft YaHei','weight' : 'bold','size' : 20}
font1 = {'family' : 'Microsoft YaHei','weight' : 'bold','size' : 30}
plt.rcParams["axes.linewidth"] = 3.0
plt.rcParams["axes.labelsize"] = 28
plt.rcParams["axes.titlepad"] = 1
plt.suptitle('Potential',size=28,weight='semibold',y=0.97)
xlimrange0=0
xlimrange1=50000
ylimrange0=-178000
ylimrange1=-170000
xtickrange= np.arange(0,50000,15000)
ytickrange= np.arange(-178000,-170000,1000)
a1=plt.subplot(1,1,1)
qdme = pd.read_csv('/home/xz3067/comp-lab-class/comp-lab-class-2023/Week2/Data/1hz3_T310.run.25000000.energyNew.xvg')
qdme.columns=["time","Potential","Kinetic","Total" ,"Temperature","Pressure","Volume"]
t = qdme["time"]
e1 = qdme["Potential"]
e2 = qdme["Kinetic"]
e3 = qdme["Total"]
e4 = qdme["Temperature"]
e5 = qdme["Pressure"]
e6 = qdme["Volume"]

plt.plot(t,e1, color = 'blue',linewidth=4.0, linestyle= '-',label ='Potential',ms=10)
#plt.plot(t,e2, color = 'blue',linewidth=4.0, linestyle= '-',label ='Kinetic',ms=10)
#plt.plot(t,e3, color = 'blue',linewidth=4.0, linestyle= '-',label ='Total',ms=10)
#plt.plot(t,e4, color = 'blue',linewidth=4.0, linestyle= '-',label ='Temperature',ms=10)
#plt.plot(t,e5, color = 'blue',linewidth=4.0, linestyle= '-',label ='Pressure',ms=10)
#plt.plot(t,e6, color = 'blue',linewidth=4.0, linestyle= '-',label ='Volume',ms=10)

plt.legend(frameon=False,loc="upper center",prop=font)

plt.yticks(fontproperties = 'Microsoft YaHei',weight='bold')
plt.xticks(xtickrange,fontproperties = 'Microsoft YaHei',weight='bold')
plt.xlim(xlimrange0,xlimrange1)
plt.ylim(ylimrange0,ylimrange1)
#plt.yscale('log')
plt.tick_params(direction='in',labelsize=24, length=10, width=3,top=True,right=True)
plt.xlabel(r'time / ns',font1)
plt.ylabel(r'Energy',font1)
plt.subplots_adjust(wspace=0,hspace=0,left=0.15)
plt.savefig('../Figures/Potential.pdf', dpi=500, bbox_inches='tight',facecolor='white')
# Out:
# findfont: Font family ['Microsoft YaHei'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Microsoft YaHei'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Microsoft YaHei'] not found. Falling back to DejaVu Sans.

# %%
import numpy as np
import pandas as pd
import os
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.figure(figsize=(7,6),dpi=600)
font = {'family' : 'Microsoft YaHei','weight' : 'bold','size' : 20}
font1 = {'family' : 'Microsoft YaHei','weight' : 'bold','size' : 30}
plt.rcParams["axes.linewidth"] = 3.0
plt.rcParams["axes.labelsize"] = 28
plt.rcParams["axes.titlepad"] = 1
plt.suptitle('Kinetic',size=28,weight='semibold',y=0.97)
xlimrange0=0
xlimrange1=50000
ylimrange0=32000
ylimrange1=38000
xtickrange= np.arange(0,50000,15000)
ytickrange= np.arange(30000,39000,1500)
a1=plt.subplot(1,1,1)
qdme = pd.read_csv('/home/xz3067/comp-lab-class/comp-lab-class-2023/Week2/Data/1hz3_T310.run.25000000.energyNew.xvg')
qdme.columns=["time","Potential","Kinetic","Total" ,"Temperature","Pressure","Volume"]
t = qdme["time"]
e1 = qdme["Potential"]
e2 = qdme["Kinetic"]
e3 = qdme["Total"]
e4 = qdme["Temperature"]
e5 = qdme["Pressure"]
e6 = qdme["Volume"]

#plt.plot(t,e1, color = 'blue',linewidth=4.0, linestyle= '-',label ='Potential',ms=10)
plt.plot(t,e2, color = 'blue',linewidth=4.0, linestyle= '-',label ='Kinetic',ms=10)
#plt.plot(t,e3, color = 'blue',linewidth=4.0, linestyle= '-',label ='Total',ms=10)
#plt.plot(t,e4, color = 'blue',linewidth=4.0, linestyle= '-',label ='Temperature',ms=10)
#plt.plot(t,e5, color = 'blue',linewidth=4.0, linestyle= '-',label ='Pressure',ms=10)
#plt.plot(t,e6, color = 'blue',linewidth=4.0, linestyle= '-',label ='Volume',ms=10)

plt.legend(frameon=False,loc="upper center",prop=font)

plt.yticks(fontproperties = 'Microsoft YaHei',weight='bold')
plt.xticks(xtickrange,fontproperties = 'Microsoft YaHei',weight='bold')
plt.xlim(xlimrange0,xlimrange1)
plt.ylim(ylimrange0,ylimrange1)
#plt.yscale('log')
plt.tick_params(direction='in',labelsize=24, length=10, width=3,top=True,right=True)
plt.xlabel(r'time / ns',font1)
plt.ylabel(r'Energy',font1)
plt.subplots_adjust(wspace=0,hspace=0,left=0.15)
plt.savefig('../Figures/Kinetic.pdf', dpi=500, bbox_inches='tight',facecolor='white')

# %%
import numpy as np
import pandas as pd
import os
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.figure(figsize=(7,6),dpi=600)
font = {'family' : 'Microsoft YaHei','weight' : 'bold','size' : 20}
font1 = {'family' : 'Microsoft YaHei','weight' : 'bold','size' : 30}
plt.rcParams["axes.linewidth"] = 3.0
plt.rcParams["axes.labelsize"] = 28
plt.rcParams["axes.titlepad"] = 1
plt.suptitle('Total',size=28,weight='semibold',y=0.97)
xlimrange0=0
xlimrange1=50000
ylimrange0=-144000
ylimrange1=-138000
xtickrange= np.arange(0,50000,15000)
ytickrange= np.arange(-145000,-135000,2000)
a1=plt.subplot(1,1,1)
qdme = pd.read_csv('/home/xz3067/comp-lab-class/comp-lab-class-2023/Week2/Data/1hz3_T310.run.25000000.energyNew.xvg')
qdme.columns=["time","Potential","Kinetic","Total" ,"Temperature","Pressure","Volume"]
t = qdme["time"]
e1 = qdme["Potential"]
e2 = qdme["Kinetic"]
e3 = qdme["Total"]
e4 = qdme["Temperature"]
e5 = qdme["Pressure"]
e6 = qdme["Volume"]

#plt.plot(t,e1, color = 'blue',linewidth=4.0, linestyle= '-',label ='Potential',ms=10)
#plt.plot(t,e2, color = 'blue',linewidth=4.0, linestyle= '-',label ='Kinetic',ms=10)
plt.plot(t,e3, color = 'blue',linewidth=4.0, linestyle= '-',label ='Total',ms=10)
#plt.plot(t,e4, color = 'blue',linewidth=4.0, linestyle= '-',label ='Temperature',ms=10)
#plt.plot(t,e5, color = 'blue',linewidth=4.0, linestyle= '-',label ='Pressure',ms=10)
#plt.plot(t,e6, color = 'blue',linewidth=4.0, linestyle= '-',label ='Volume',ms=10)

plt.legend(frameon=False,loc="upper center",prop=font)

plt.yticks(fontproperties = 'Microsoft YaHei',weight='bold')
plt.xticks(xtickrange,fontproperties = 'Microsoft YaHei',weight='bold')
plt.xlim(xlimrange0,xlimrange1)
plt.ylim(ylimrange0,ylimrange1)
#plt.yscale('log')
plt.tick_params(direction='in',labelsize=24, length=10, width=3,top=True,right=True)
plt.xlabel(r'time / ns',font1)
plt.ylabel(r'Energy',font1)
plt.subplots_adjust(wspace=0,hspace=0,left=0.15)
plt.savefig('../Figures/Total.pdf', dpi=500, bbox_inches='tight',facecolor='white')

# %%
import numpy as np
import pandas as pd
import os
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.figure(figsize=(7,6),dpi=600)
font = {'family' : 'Microsoft YaHei','weight' : 'bold','size' : 20}
font1 = {'family' : 'Microsoft YaHei','weight' : 'bold','size' : 30}
plt.rcParams["axes.linewidth"] = 3.0
plt.rcParams["axes.labelsize"] = 28
plt.rcParams["axes.titlepad"] = 1
plt.suptitle('Temperature',size=28,weight='semibold',y=0.97)
xlimrange0=0
xlimrange1=50000
ylimrange0=280
ylimrange1=350
xtickrange= np.arange(0,50000,15000)
ytickrange= np.arange(250,400,200)
a1=plt.subplot(1,1,1)
qdme = pd.read_csv('/home/xz3067/comp-lab-class/comp-lab-class-2023/Week2/Data/1hz3_T310.run.25000000.energyNew.xvg')
qdme.columns=["time","Potential","Kinetic","Total" ,"Temperature","Pressure","Volume"]
t = qdme["time"]
e1 = qdme["Potential"]
e2 = qdme["Kinetic"]
e3 = qdme["Total"]
e4 = qdme["Temperature"]
e5 = qdme["Pressure"]
e6 = qdme["Volume"]

#plt.plot(t,e1, color = 'blue',linewidth=4.0, linestyle= '-',label ='Potential',ms=10)
#plt.plot(t,e2, color = 'blue',linewidth=4.0, linestyle= '-',label ='Kinetic',ms=10)
#plt.plot(t,e3, color = 'blue',linewidth=4.0, linestyle= '-',label ='Total',ms=10)
plt.plot(t,e4, color = 'blue',linewidth=4.0, linestyle= '-',label ='Temperature',ms=10)
#plt.plot(t,e5, color = 'blue',linewidth=4.0, linestyle= '-',label ='Pressure',ms=10)
#plt.plot(t,e6, color = 'blue',linewidth=4.0, linestyle= '-',label ='Volume',ms=10)

plt.legend(frameon=False,loc="upper center",prop=font)

plt.yticks(fontproperties = 'Microsoft YaHei',weight='bold')
plt.xticks(xtickrange,fontproperties = 'Microsoft YaHei',weight='bold')
plt.xlim(xlimrange0,xlimrange1)
plt.ylim(ylimrange0,ylimrange1)
#plt.yscale('log')
plt.tick_params(direction='in',labelsize=24, length=10, width=3,top=True,right=True)
plt.xlabel(r'time / ns',font1)
plt.ylabel(r'Temperature',font1)
plt.subplots_adjust(wspace=0,hspace=0,left=0.15)
plt.savefig('../Figures/Temperature.pdf', dpi=500, bbox_inches='tight',facecolor='white')

# %%
import numpy as np
import pandas as pd
import os
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.figure(figsize=(7,6),dpi=600)
font = {'family' : 'Microsoft YaHei','weight' : 'bold','size' : 20}
font1 = {'family' : 'Microsoft YaHei','weight' : 'bold','size' : 30}
plt.rcParams["axes.linewidth"] = 3.0
plt.rcParams["axes.labelsize"] = 28
plt.rcParams["axes.titlepad"] = 1
plt.suptitle('Pressure',size=28,weight='semibold',y=0.97)
xlimrange0=0
xlimrange1=50000
ylimrange0=-1000
ylimrange1=1000
xtickrange= np.arange(0,50000,15000)
ytickrange= np.arange(-2000,2000,500)
a1=plt.subplot(1,1,1)
qdme = pd.read_csv('/home/xz3067/comp-lab-class/comp-lab-class-2023/Week2/Data/1hz3_T310.run.25000000.energyNew.xvg')
qdme.columns=["time","Potential","Kinetic","Total" ,"Temperature","Pressure","Volume"]
t = qdme["time"]
e1 = qdme["Potential"]
e2 = qdme["Kinetic"]
e3 = qdme["Total"]
e4 = qdme["Temperature"]
e5 = qdme["Pressure"]
e6 = qdme["Volume"]

#plt.plot(t,e1, color = 'blue',linewidth=4.0, linestyle= '-',label ='Potential',ms=10)
#plt.plot(t,e2, color = 'blue',linewidth=4.0, linestyle= '-',label ='Kinetic',ms=10)
#plt.plot(t,e3, color = 'blue',linewidth=4.0, linestyle= '-',label ='Total',ms=10)
#plt.plot(t,e4, color = 'blue',linewidth=4.0, linestyle= '-',label ='Temperature',ms=10)
plt.plot(t,e5, color = 'blue',linewidth=4.0, linestyle= '-',label ='Pressure',ms=10)
#plt.plot(t,e6, color = 'blue',linewidth=4.0, linestyle= '-',label ='Volume',ms=10)

plt.legend(frameon=False,loc="upper center",prop=font)

plt.yticks(fontproperties = 'Microsoft YaHei',weight='bold')
plt.xticks(xtickrange,fontproperties = 'Microsoft YaHei',weight='bold')
plt.xlim(xlimrange0,xlimrange1)
plt.ylim(ylimrange0,ylimrange1)
#plt.yscale('log')
plt.tick_params(direction='in',labelsize=24, length=10, width=3,top=True,right=True)
plt.xlabel(r'time / ns',font1)
plt.ylabel(r'Pressure',font1)
plt.subplots_adjust(wspace=0,hspace=0,left=0.15)
plt.savefig('../Figures/Pressure.pdf', dpi=500, bbox_inches='tight',facecolor='white')

# %%
import numpy as np
import pandas as pd
import os
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.figure(figsize=(7,6),dpi=600)
font = {'family' : 'Microsoft YaHei','weight' : 'bold','size' : 20}
font1 = {'family' : 'Microsoft YaHei','weight' : 'bold','size' : 30}
plt.rcParams["axes.linewidth"] = 3.0
plt.rcParams["axes.labelsize"] = 28
plt.rcParams["axes.titlepad"] = 1
plt.suptitle('Volume',size=28,weight='semibold',y=0.97)
xlimrange0=0
xlimrange1=50000
ylimrange0=100
ylimrange1=150
xtickrange= np.arange(0,50000,15000)
ytickrange= np.arange(20,200,10)
a1=plt.subplot(1,1,1)
qdme = pd.read_csv('/home/xz3067/comp-lab-class/comp-lab-class-2023/Week2/Data/1hz3_T310.run.25000000.energyNew.xvg')
qdme.columns=["time","Potential","Kinetic","Total" ,"Temperature","Pressure","Volume"]
t = qdme["time"]
e1 = qdme["Potential"]
e2 = qdme["Kinetic"]
e3 = qdme["Total"]
e4 = qdme["Temperature"]
e5 = qdme["Pressure"]
e6 = qdme["Volume"]

#plt.plot(t,e1, color = 'blue',linewidth=4.0, linestyle= '-',label ='Potential',ms=10)
#plt.plot(t,e2, color = 'blue',linewidth=4.0, linestyle= '-',label ='Kinetic',ms=10)
#plt.plot(t,e3, color = 'blue',linewidth=4.0, linestyle= '-',label ='Total',ms=10)
#plt.plot(t,e4, color = 'blue',linewidth=4.0, linestyle= '-',label ='Temperature',ms=10)
#plt.plot(t,e5, color = 'blue',linewidth=4.0, linestyle= '-',label ='Pressure',ms=10)
plt.plot(t,e6, color = 'blue',linewidth=4.0, linestyle= '-',label ='Volume',ms=10)

plt.legend(frameon=False,loc="upper center",prop=font)

plt.yticks(fontproperties = 'Microsoft YaHei',weight='bold')
plt.xticks(xtickrange,fontproperties = 'Microsoft YaHei',weight='bold')
plt.xlim(xlimrange0,xlimrange1)
plt.ylim(ylimrange0,ylimrange1)
#plt.yscale('log')
plt.tick_params(direction='in',labelsize=24, length=10, width=3,top=True,right=True)
plt.xlabel(r'time / ns',font1)
plt.ylabel(r'Volume',font1)
plt.subplots_adjust(wspace=0,hspace=0,left=0.15)
plt.savefig('../Figures/Volume.pdf', dpi=500, bbox_inches='tight',facecolor='white')

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0,50000,15000)

qdme = pd.read_csv('/home/xz3067/comp-lab-class/comp-lab-class-2023/Week2/Data/1hz3_T310.run.25000000.energyNew.xvg')
qdme.columns=["time","Potential","Kinetic","Total" ,"Temperature","Pressure","Volume"]
t = qdme["time"]
e1 = qdme["Potential"]
e2 = qdme["Kinetic"]
e3 = qdme["Total"]
e4 = qdme["Temperature"]
e5 = qdme["Pressure"]
e6 = qdme["Volume"]

fig, ax1 = plt.subplots( 1, 1, figsize=(9,3) )
ax1.plot( t, e4, color='blue', linewidth=10,linestyle= '-',label ='Temperature')
ax2 = ax1.twinx()
ax2.plot( t, e2, color='red', linewidth=2,linestyle= '-',label ='Kinetic')
ax1.yaxis.tick_right()
ax2.yaxis.tick_left()
ax1.legend(frameon=False,loc="upper right")
ax2.legend(frameon=False,loc="upper center")
plt.savefig('../Figures/Temperature_Kinetic.pdf', dpi=500, bbox_inches='tight',facecolor='white')
